# %%
import subprocess
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
sns.set_style('whitegrid')

# %%
from etl_demo import show_counts_and_preview, plot_avg_price_by_year, plot_top_regions, plot_price_distribution
DB_PATH = '/Users/sm/Developer/Projects/Danish Residential Housing EDA/Data/warehouse.db'

# %%
show_counts_and_preview(db_path=DB_PATH)
# Out:
#    staging_rows  dim_date_rows  dim_property_rows  fact_sales_rows
# 0           100          11254             100000           100000
#
# Sample rows from fact_sales:
#    house_id        date    sales_type  purchase_price  pct_change   sqm_price
# 0        16  2024-10-24  regular_sale         6500000        -3.0  45774.6500
# 1        13  2024-10-24  regular_sale         3400000         0.0  73913.0500
# 2        60  2024-10-23  regular_sale         4550000        -4.0  40625.0000
# 3        29  2024-10-23  regular_sale         1630000       -12.0   8763.4400
# 4        92  2024-10-22  regular_sale         1975000       -10.0  24085.3650
# 5        82  2024-10-22  regular_sale         1850000         0.0  12012.9870
# 6       100  2024-10-22  regular_sale          360000         0.0   8571.4290
# 7       125  2024-10-21   family_sale          700000         0.0  11290.3220
# 8       150  2024-10-20  regular_sale          500000         0.0   2475.2476
# ...

# %%
plot_avg_price_by_year(DB_PATH)

# %%
plot_top_regions(DB_PATH)

# %%
plot_price_distribution(DB_PATH)
